# %% [markdown]
# # Exercise 16

# %% [markdown]
# ## a)
# <img src="files/exercise16.png">

# %% [markdown]
# Leider hatten wir nicht genug Zeit, Kraft und vor allem Kompetenz um weiter zu machen. Daher gibt es als Entschädigung ein tolles Youtube Musik Video mit Hupen:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('PcRyjkYdDxM', width=800, height=500)
