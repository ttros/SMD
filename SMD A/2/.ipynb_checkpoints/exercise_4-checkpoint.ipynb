# %%
# importing extensions
import numpy as np
import matplotlib.pyplot as plt
import sympy as smp
import scipy.optimize as opt

smp.init_printing()

# defining constants

k_b = 1.3* 10**(-23) # unit: (m^2*kg)/(s^2*K^1) 

# defining function

def f(v, N, T, m, k_b):
    return (N * smp.exp(((-1)*(v**2)*m)/(2*k_b*T))*4*smp.pi*v**2)

#xx=np.linspace(0,10,100)
#plt.plot(xx,f(xx,1,1,1,k_b))
#plt.show()
#plt.close()

# %% [markdown]
# The normalization constant makes sure, that the function integrated over the whole area equals 1, therefore we can calculate it, by calculating the definite integral from $-\infty$ to $+\infty$ and making it equal 1.

# %%
# determining the normalization constant N

N, T, m, k_b= smp.symbols('N T m k_b', real = True, positive = True)
v = smp.symbols('v', real = True)
f_int = smp.integrate(f,(v,0,smp.oo))
#f_int = smp.integrate(f, (v, -(smp.oo), smp.oo))
N = smp.solve(f_int-1, N)
print(f'N = {N} \nAnd also a prettier symbolize output:')
N
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Error from parse_expr with transformed code: "<Symbol ('function' )Symbol ('f' )Symbol ('at' )Integer (0x7f4b7ad93ca0 )>"
#
# The above exception was the direct cause of the following exception:
#
# SyntaxError                               Traceback (most recent call last)
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/core/sympify.py:495, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     494     a = a.replace('\n', '')
# --> 495     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     496 except (TokenError, SyntaxError) as exc:
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py:1105, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1104     local_dict[i] = null
# -> 1105 raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py:1096, in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1095 try:
# -> 1096     rv = eval_expr(code, local_dict, global_dict)
#    1097     # restore neutral definitions for names
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/parsing/sympy_parser.py:915, in eval_expr(code, local_dict, global_dict)
#     910 """
#     911 Evaluate Python code generated by ``stringify_expr``.
#     912
#     913 Generally, ``parse_expr`` should be used.
#     914 """
# --> 915 expr = eval(
#     916     code, global_dict, local_dict)  # take local objects in preference
#     917 return expr
#
# SyntaxError: invalid syntax (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# Input In [50], in <cell line: 5>()
#       3 N, T, m, k_b= smp.symbols('N T m k_b', real = True, positive = True)
#       4 v = smp.symbols('v',real = True)
# ----> 5 f_int = smp.integrate(f,(v,0,smp.oo))
#       6 #f_int = smp.integrate(f, (v, -(smp.oo), smp.oo))
#       7 N = smp.solve(f_int-1, N)
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/integrals/integrals.py:1563, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1399 """integrate(f, var, ...)
#    1400
#    1401 .. deprecated:: 1.6
#    (...)
#    1553
#    1554 """
#    1555 doit_flags = {
#    1556     'deep': False,
#    1557     'meijerg': meijerg,
#    (...)
#    1561     'manual': manual
#    1562     }
# -> 1563 integral = Integral(*args, **kwargs)
#    1565 if isinstance(integral, Integral):
#    1566     return integral.doit(**doit_flags)
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/integrals/integrals.py:99, in Integral.__new__(cls, function, *symbols, **assumptions)
#      89 if isinstance(function, Poly):
#      90     sympy_deprecation_warning(
#      91         """
#      92         integrate(Poly) and Integral(Poly) are deprecated. Instead,
#    (...)
#      96         deprecated_since_version="1.6",
#      97         active_deprecations_target="deprecated-integrate-poly")
# ---> 99 obj = AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#     100 return obj
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/concrete/expr_with_limits.py:545, in AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#     543 def __new__(cls, function, *symbols, **assumptions):
#     544     from sympy.concrete.summations import Sum
# --> 545     pre = _common_new(cls, function, *symbols,
#     546         discrete=issubclass(cls, Sum), **assumptions)
#     547     if isinstance(pre, tuple):
#     548         function, limits, orientation = pre
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/concrete/expr_with_limits.py:26, in _common_new(cls, function, discrete, *symbols, **assumptions)
#      22 def _common_new(cls, function, *symbols, discrete, **assumptions):
#      23     """Return either a special return value or the tuple,
#      24     (function, limits, orientation). This code is common to
#      25     both ExprWithLimits and AddWithLimits."""
# ---> 26     function = sympify(function)
#      28     if isinstance(function, Equality):
#      29         # This transforms e.g. Integral(Eq(x, y)) to Eq(Integral(x), Integral(y))
#      30         # but that is only valid for definite integrals.
#      31         limits, orientation = _process_limits(*symbols, discrete=discrete)
#
# File ~/.local/anaconda3/lib/python3.8/site-packages/sympy/core/sympify.py:497, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     495     expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     496 except (TokenError, SyntaxError) as exc:
# --> 497     raise SympifyError('could not parse %r' % a, exc)
#     499 return expr
#
# SympifyError: Sympify of expression 'could not parse '<function f at 0x7f4b7ad93ca0>'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)

# %% [markdown]
# A)

# %% [markdown]
# The most probable velocity $v_m$ ist the maximum of $f(v)$. We have to calculate the derivative and make it equal 0.

# %%
f_diff=smp.diff(f,v)
v_m = smp.solve(f_diff, v)
print(f'the most probable velocity v_m is v_m(m, T) = {v_m} \nAnd again the symbolized output:')
v_m
# Out:
# the most probable velocity v_m is v_m(m, T) = [0, -sqrt(2)*sqrt(T)*sqrt(k_b)/sqrt(m), sqrt(2)*sqrt(T)*sqrt(k_b)/sqrt(m)]
# And again the symbolized output:
# ⎡            _____           _____⎤
# ⎢   -√2⋅√T⋅╲╱ k_b    √2⋅√T⋅╲╱ k_b ⎥
# ⎢0, ───────────────, ─────────────⎥
# ⎣          √m              √m     ⎦

# %% [markdown]
# B)

# %% [markdown]
# The mean of a value $x$ of a distribution $f(x)$ is given by
# \begin{equation}
#     E[X] = \int_{-\infty}^{+\infty} x f(x) \,dx
# \end{equation}

# %%
#calculating the mean of v
N_1 = smp.symbols('N_1', real = True, positive = True)
f_v = N_1 * smp.exp(-v**2*v_m[0]**(-1))*4*smp.pi*v**2
v_mean = smp.integrate(f_v*v, (v, -(smp.oo), smp.oo))
print(f'the mean of the velocity is v_mean = {v_mean}')

# %% [markdown]
# C)

# %%
#The median is the distributions 0.5-quantile

# %% [markdown]
# D)
