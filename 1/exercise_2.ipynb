# %% [markdown]
# Exercise 2

# %%
#importing extensions
import numpy as np
import matplotlib.pyplot as plt

# defining constants
m = 511 * 10**3 # unit: eV

# defining function
def f(E, theta):
    gamma = E/m
    beta = np.sqrt(1-gamma**-2)
    return ((2+(np.sin(theta)**2))/(1-beta**2*(np.cos(theta))**2))

# %%
x = 10**-7
xx = np.linspace(-x,x,10000)
plt.plot(xx,f(50*10**5,xx))
plt.show()
plt.close()

# %%
def g(E,theta):
    gamma = E/m
    beta = np.sqrt(1-gamma**-2)
    return ((2+(np.sin(theta)**2))/(gamma**-2+(1-gamma**-2)*(np.sin(theta))**2))

# %%
x = 0.5*10**-7
xx = np.linspace(-x,x,10000)
plt.plot(xx,f(50*10**9,xx))
plt.plot(xx,g(50*10**9,xx))
plt.show()
plt.close()

# %%
xx = np.linspace(-0.1,np.pi+0.1,10000)
E = 50 * 10**5
gamma = E/m
plt.plot(xx,f(E,xx))
plt.show()
plt.close()
