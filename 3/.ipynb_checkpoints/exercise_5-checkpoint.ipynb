# %% [markdown]
# B)

# %% [markdown]
# we use the recursive function $x_{j+1} = ((a \cdot x_j + c) \mod{m})$ to determine the period length of the sequence of randomly generated numbers.
#
# The given values are $c = 3$ and $m = 1024$. We start with $x_0 = 0$ and choose three different values of $a$: two, three and four.

# %%
import numpy as np
from project_a2.random import LCG

def array(state, state_array):
    for n in range(len(state_array)):
        if  state == state_array[n]:
            return 0
    return 1

def length_check(a_):
    n = 0
    generator = LCG(0, a=a_, c=3, m=1024)
    current_state = np.zeros(1023)
    generator.advance()
    while n != 1023 and (generator.state != 0) and array(generator.state, current_state):
        current_state[n] = generator.state
        generator.advance()
        n += 1
        #print(generator.state)
    return n

print(f'a20 = {length_check(20)}')
print(f'a30 = {length_check(30)}')
print(f'a40 = {length_check(40)}')
print(f'a9 = {length_check(9)}')
# Out:
# a20 = 5
# a30 = 10
# a40 = 4
# a9 = 1023

# %% [markdown]
# for $a= 20$ the period length is $5$, for $a= 30$ it is $10$, for $a= 40$ it is $4$ and for $a=9$ the period length is $1023$.
#
# Maximum period length:
#
# The four requirements for the maximum period length are $c \neq 0$, $c$ and $m$ are coprime, each prime factor of $m$ divides $(a-1)$ and if $m$ is divisible by 4, so is $(a-1)$.
#
# Only the last two requirements are dependend on $a$, so we will check for which values of $a$ these apply.
#
# $m$ only has the prime factor $2$, so $(a-1)$ has to be devisible by $2$. Also, $m$ is devisible by $4$, so $(a-1)$ has to be as well.
#
# Every number that is devisible by $4$ is also devisible by $2$, but not the other way around. That is why every $a$ has to be $a = (n \cdot 4) + 1$ with $n \in \mathbb{N}_{>0}$.

# %% [markdown]
# Interpretation of the lcg PDF:
#
# The distribution seems to be random, so the method works.

# %% [markdown]
# D)

# %%
import matplotlib .pyplot as plt
import numpy as np
from project_a2.random import LCG

random = np.random.default_rng(666)
generator = LCG(0, a=1601, c=3456, m=10000)
x1, y1, z1 = generator.uniform(size =(3, 10000))

plt.hist(x1, 100)
#plt.show ()
# Out:
# (array([112.,  96.,  96.,  96., 112.,  96.,  96.,  96., 112.,  96.,  96.,
#          96., 112.,  96.,  96.,  96., 112.,  96.,  96.,  96., 112.,  96.,
#          96.,  96.,  96., 112.,  96.,  96.,  96., 112.,  96.,  96.,  96.,
#         112.,  96.,  96.,  96., 112.,  96.,  96.,  96., 112.,  96.,  96.,
#          96., 112.,  96.,  96.,  96.,  96., 112.,  96.,  96.,  96., 112.,
#          96.,  96.,  96., 112.,  96.,  96.,  96., 112.,  96.,  96.,  96.,
#         112.,  96.,  96.,  96., 112.,  96.,  96.,  96.,  96., 112.,  96.,
#          96.,  96., 112.,  96.,  96.,  96., 112.,  96.,  96.,  96., 112.,
#          96.,  96.,  96., 112.,  96.,  96.,  96., 112.,  96.,  96.,  96.,
#         112.]),
#  array([0.      , 0.009984, 0.019968, 0.029952, 0.039936, 0.04992 ,
#         0.059904, 0.069888, 0.079872, 0.089856, 0.09984 , 0.109824,
#         0.119808, 0.129792, 0.139776, 0.14976 , 0.159744, 0.169728,
#         0.179712, 0.189696, 0.19968 , 0.209664, 0.219648, 0.229632,
#         0.239616, 0.2496  , 0.259584, 0.269568, 0.279552, 0.289536,
#         0.29952 , 0.309504, 0.319488, 0.329472, 0.339456, 0.34944 ,
#         0.359424, 0.369408, 0.379392, 0.389376, 0.39936 , 0.409344,
#         0.419328, 0.429312, 0.439296, 0.44928 , 0.459264, 0.469248,
#         0.479232, 0.489216, 0.4992  , 0.509184, 0.519168, 0.529152,
#         0.539136, 0.54912 , 0.559104, 0.569088, 0.579072, 0.589056,
#         0.59904 , 0.609024, 0.619008, 0.628992, 0.638976, 0.64896 ,
#         0.658944, 0.668928, 0.678912, 0.688896, 0.69888 , 0.708864,
#         0.718848, 0.728832, 0.738816, 0.7488  , 0.758784, 0.768768,
#         0.778752, 0.788736, 0.79872 , 0.808704, 0.818688, 0.828672,
#         0.838656, 0.84864 , 0.858624, 0.868608, 0.878592, 0.888576,
#         0.89856 , 0.908544, 0.918528, 0.928512, 0.938496, 0.94848 ,
#         0.958464, 0.968448, 0.978432, 0.988416, 0.9984  ]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# The result does not meet the requirements of a good random generator, since the output does not really seem to be random.
#
# Changing the initial value $x_0$ would result in a more randomized result.

# %% [markdown]
# E)

# %%
#e)

fig = plt.figure ()

ax = fig. add_subplot (1, 1, 1)

ax.scatter(
    x1, y1,
    s=5, # smaller points
    alpha =0.3 , # 70% transparency
)
# set the orientation of the 3d axis

#plt.show ()


#3-dimensional

fig = plt.figure ()

ax = fig. add_subplot (1, 1, 1, projection ='3d')

ax.scatter(
    x1, y1, z1,
    s=5, # smaller points
    alpha =0.3 , # 70% transparency
)
# set the orientation of the 3d axis
ax. view_init (elev =30, azim =20)
#plt.show ()

# %% [markdown]
# Same unrandom result as in task D). The result for the chosen initial value does not seem to be random.

# %% [markdown]
# F)

# %%
#histogram
x2, y2, z2 = random.uniform(size =(3, 10000))

plt.hist(x2, 100)
#plt.show ()


#2-dimensional

fig = plt.figure ()

ax = fig. add_subplot (1, 1, 1)

ax.scatter(
    x2, y2,
    s=5, # smaller points
    alpha =0.3 , # 70% transparency
)
# set the orientation of the 3d axis

#plt.show ()


#3-dimensional

fig = plt.figure ()

ax = fig. add_subplot (1, 1, 1, projection ='3d')

ax.scatter(
    x2, y2, z2,
    s=5, # smaller points
    alpha =0.3 , # 70% transparency
)
# set the orientation of the 3d axis
ax. view_init (elev =30, azim =20)
#plt.show ()
